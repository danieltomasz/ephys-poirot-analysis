# %%
# Work with R kernel

# %%
library(dplyr)
library(here)
library(tidyverse)
library(readxl)
library(tidyr)
library(ggseg)
library(ggseg3d)
library(ggsegDesterieux)
# Out:
# Dolaczanie pakietu: 'dplyr'
#
#
# Nastepujace obiekty zostaly zakryte z 'package:stats':
#
#     filter, lag
#
#
# Nastepujace obiekty zostaly zakryte z 'package:base':
#
#     intersect, setdiff, setequal, union
#
#
# here() starts at /Users/daniel/PhD/Projects/ephys-poirot-analysis
#
# -- Attaching core tidyverse packages ------------------------ tidyverse 2.0.0 --
# v forcats   1.0.0     v readr     2.1.4
# v ggplot2   3.4.2     v stringr   1.5.0
# v lubridate 1.9.2     v tibble    3.2.1
# v purrr     1.0.1     v tidyr     1.3.0
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()
# i Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
vector <- 2:5

# %%
library(ggseg)
library(ggplot2)
plot(dk)
# Out:
# plot without title

# %% [markdown]
# [Adding external data to ggseg plotting • ggseg](https://ggseg.github.io/ggseg/articles/externalData.html)
