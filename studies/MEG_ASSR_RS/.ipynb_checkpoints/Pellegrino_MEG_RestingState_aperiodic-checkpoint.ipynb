# %% [raw]
# ---
# title: "Reanalysing resting state data accompanied MEG ASSR Analysis"
# author: "Daniel Borek"
# execute:
#     echo: false
# date: today
# format:
#     html:
#         theme: cosmo
#         fontsize: 1.1em
#         linestretch: 1.7
# jupyter: poirot-3.11.3
# ---

# %% [markdown]
# # Analysis description
#
# Estimating parameters parametrizing resting state EEG data.
#  Steps of Analysis:
#  - `01_load_data.py` Load data into xarray
#  - `02_compute_spectrum.py` Compute spectrum and save into intermediate file
#  - `03_estimate_parameters.py` Estimate parameters

# %%
from IPython.lib.deepreload import reload
# %load_ext autoreload
# %autoreload 2

# %%
# %cd '/Users/daniel/PhD/Projects/ephys-poirot-analysis/studies/MEG_ASSR_RS'
# !python '01_load_data.py'
# Out:
# /Users/daniel/PhD/Projects/ephys-poirot-analysis/studies/MEG_ASSR_RS
# 100%|███████████████████████████████████████████| 15/15 [01:23<00:00,  5.55s/it]

# %%
# !python '02_compute_spectrum.py'
# Out:
# Traceback (most recent call last):
#   File "/Users/daniel/PhD/Projects/ephys-poirot-analysis/studies/MEG_ASSR_RS/02_compute_spectrum.py", line 34, in <module>
#     ds = xr.open_dataarray(f"{folder}/output/{subject}_MEG_ASSR_times.nc")
#                               ^^^^^^
# NameError: name 'folder' is not defined. Did you mean: 'filter'?

# %% [markdown]
# # Aplying function to `xarray`  object

# %%
display(df)
# Out:
# Item Description:   0%|          | 0/15 [00:00<?, ?it/s]
# S001
# ...
# Item Description:   7%|▋         | 1/15 [00:05<01:15,  5.38s/it]
# S002
# ...
# Item Description:  13%|█▎        | 2/15 [00:12<01:26,  6.62s/it]
# S003
# ...
# Item Description:  20%|██        | 3/15 [00:18<01:11,  5.96s/it]
# S004
# ...
# Item Description:  27%|██▋       | 4/15 [00:25<01:11,  6.54s/it]
# S005
# ...
# Item Description:  33%|███▎      | 5/15 [00:32<01:06,  6.68s/it]
# S006
# ...
# Item Description:  40%|████      | 6/15 [00:38<00:57,  6.43s/it]
# S007
# ...
# Item Description:  47%|████▋     | 7/15 [00:43<00:49,  6.17s/it]
# S008
# ...
# Item Description:  53%|█████▎    | 8/15 [00:52<00:47,  6.77s/it]
# S009
# ...
# Item Description:  60%|██████    | 9/15 [00:57<00:37,  6.29s/it]
# S010
# ...
# Item Description:  67%|██████▋   | 10/15 [01:02<00:29,  5.92s/it]
# S011
# ...
# Item Description:  73%|███████▎  | 11/15 [01:07<00:22,  5.65s/it]
# S012
# ...
# Item Description:  80%|████████  | 12/15 [01:13<00:17,  5.72s/it]
# S013
# ...

# %% [markdown]
# Due to problems with how xarray handle group_by I am trying to use pandas multinidex

# %%
# z = q.stack(xsession=("trial","iter_number"))
# y = q.set_index(labit=["labels","iter_number"]).groupby('labit').mean()
y = q.mean("trial").mean("iter_number").mean(
    "session").mean("sub").groupby("regions").mean("labels")
display(y)
# Out:
# <xarray.DataArray (regions: 14, freqs: 1201)>
# array([[2.06646253e-26, 6.83690858e-27, 1.12762187e-25, ...,
#         1.30395783e-36, 1.35510159e-36, 7.40022398e-37],
#        [2.45475850e-26, 8.38090806e-27, 1.96257940e-25, ...,
#         1.17068697e-36, 1.30306526e-36, 7.35801108e-37],
#        [9.71416409e-26, 3.38179570e-26, 6.66013241e-25, ...,
#         3.56739616e-36, 3.93795742e-36, 2.17553262e-36],
#        ...,
#        [1.84269410e-26, 6.15894372e-27, 1.00840954e-25, ...,
#         7.08601105e-37, 7.77242215e-37, 3.86439911e-37],
#        [2.43149442e-25, 8.06532367e-26, 1.93482596e-24, ...,
#         6.38310283e-36, 7.29536827e-36, 4.30919334e-36],
#        [5.66360539e-25, 1.88901907e-25, 3.33165072e-24, ...,
#         6.46086098e-36, 8.52967804e-36, 5.50117229e-36]])
# Coordinates:
#   * freqs    (freqs) float64 0.0 0.25 0.5 0.75 1.0 ... 299.2 299.5 299.8 300.0
#   * regions  (regions) object 'LC' 'LF' 'LL' 'LO' 'LP' ... 'RO' 'RP' 'RPF' 'RT'

# %%
from matplotlib import pyplot as plt
fig, ax = plt.subplots(layout='constrained')

y.isel(regions=slice(0, 13)).plot.line(
    x="freqs", xlim=[1, 50], yscale='log', xscale='log')
# fig.legend(loc='outside right upper')
plt.show()

# %% [markdown]
# # Now is time for actual planning and analysis
#
# # I want to show  the vales from foof comming from resting state brain

# %%
xs = q.mean("trial").mean("iter_number")
display(xs._coords.keys())

# time is to compute fooof now
# Out:
# dict_keys(['labels', 'sub', 'session', 'regions', 'freqs'])

# %%
from fooof import FOOOF, FOOOFGroup


from poirot.spectrum import fooof2pandas


def specparam_attributes(xs, stacked_cols, fg, freq_range):

    xs = xs.stack(point=stacked_cols).transpose("point", "freqs")
    # assumption stacked dim is called point
    freqs = xs.freqs.values
    spectra = xs.values
    fg.fit(freqs, spectra, freq_range=freq_range, n_jobs=-1, progress="tqdm")
    df = fooof2pandas(fg)
    # get an list of additioanl columns
    l1 = ["freqs", "point"]
    l1.extend(stacked_cols)
    l2 = xs._coords.keys()
    list_of_columns = list(filter(lambda x: x not in l1, l2))
    return (
        pd.DataFrame.from_records(xs.point.values, columns=stacked_cols)
        .assign(ID=np.arange(len(xs.point.values)))
        .assign(**{column: xs[column].values for column in list_of_columns})
        .merge(df, on="ID")
        .drop(columns=["ID"])
    )


fg = FOOOFGroup(
    peak_width_limits=[2, 8],
    min_peak_height=0.1,
    max_n_peaks=6,
)

freq_range = [2, 48]

stacked_cols = ['labels', 'sub', 'session']
# xd = xs.stack(point=stacked_cols).transpose("point", "frequency")
df = specparam_attributes(xs, stacked_cols, fg, freq_range)
display(df)
# Out:
# Running FOOOFGroup: 100%|██████████| 272/272 [00:03<00:00, 70.83it/s]
#                     labels   sub   session regions         CF        PW
# 0               bankssts L  S001  Session1      LT   8.056609  0.365005  \
# 1               bankssts L  S001  Session1      LT  10.653590  0.550840
# 2               bankssts L  S001  Session1      LT  13.122014  0.304396
# 3               bankssts L  S001  Session1      LT  16.038525  0.114416
# 4               bankssts L  S001  Session1      LT  21.162669  0.118779
# ...                    ...   ...       ...     ...        ...       ...
# 1227  transversetemporal R  S002  Session1      RT  21.685376  0.345957
# 1228  transversetemporal R  S002  Session2      RT   6.472100  0.240361
# 1229  transversetemporal R  S002  Session2      RT  10.358430  0.584830
# 1230  transversetemporal R  S002  Session2      RT  14.021892  0.372810
# 1231  transversetemporal R  S002  Session2      RT  21.723957  0.270091
#
# ...
